# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/동대문구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/동대문구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/동대문구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                573               459
# 2017-02                583               423
# 2017-03                571               423
# 2017-04                584               438
# 2017-05                603               438
# 2017-06                605               478
# 2017-07                605               453
# 2017-08                680               464
# 2017-09                621               442
# 2017-10                618               477
# 2017-11                629               469
# 2017-12                648               497
# 2018-01                630               504
# 2018-02                622               492
# 2018-03                632               496
# 2018-04                651               492
# 2018-05                664               490
# 2018-06                713               534
# 2018-07                717               528
# 2018-08                780               513
# 2018-09                770               523
# 2018-10                741               524
# 2018-11                727               551
# 2018-12                751               506
# 2019-01                780               541
# 2019-02                779               548
# 2019-03                755               543
# 2019-04                793               551
# 2019-05                774               515
# 2019-06                839               510
# 2019-07                832               498
# 2019-08                863               529
# 2019-09                874               526
# 2019-10                843               534
# 2019-11                852               533
# 2019-12                871               562
# 2020-01                843               571
# 2020-02                876               582
# 2020-03                864               563
# 2020-04                923               575
# 2020-05                867               590
# 2020-06                979               607
# 2020-07                999               623
# 2020-08               1086               642
# 2020-09               1075               634
# 2020-10               1072               635
# 2020-11               1181               645
# 2020-12               1207               693
# 2021-01               1183               718
# 2021-02               1157               737
# 2021-03               1132               715
# 2021-04               1075               703
# 2021-05               1046               662
# 2021-06               1220               693
# 2021-07               1173               695
# 2021-08               1236               672
# 2021-09               1318               630
# 2021-10               1269               675
# 2021-11               1202               703
# 2021-12               1163               716

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     202
# 2017-02     194
# 2017-03     206
# 2017-04     180
# 2017-05     153
# 2017-06     166
# 2017-07     178
# 2017-08     166
# 2017-09     179
# 2017-10     170
# 2017-11     186
# 2017-12     137
# 2018-01     176
# 2018-02     143
# 2018-03     169
# 2018-04     169
# 2018-05     138
# 2018-06     141
# 2018-07     185
# 2018-08     153
# 2018-09     181
# 2018-10     141
# 2018-11     142
# 2018-12     148
# 2019-01     170
# 2019-02     148
# 2019-03     162
# 2019-04     164
# 2019-05     158
# 2019-06     150
# 2019-07     160
# 2019-08     147
# 2019-09     169
# 2019-10     174
# 2019-11     149
# 2019-12     133
# 2020-01     185
# 2020-02     139
# 2020-03     138
# 2020-04     156
# 2020-05     127
# 2020-06     147
# 2020-07     117
# 2020-08     141
# 2020-09     157
# 2020-10     132
# 2020-11     124
# 2020-12     139
# 2021-01     133
# 2021-02     115
# 2021-03     155
# 2021-04     130
# 2021-05     149
# 2021-06     138
# 2021-07     133
# 2021-08     146
# 2021-09     128
# 2021-10     135
# 2021-11     120
# 2021-12     128

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('동대문구')

plt.legend(loc="upper left")

plt.show()
