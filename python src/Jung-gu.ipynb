# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/중구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/중구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/중구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                709               563
# 2017-02                741               566
# 2017-03                756               543
# 2017-04                723               579
# 2017-05                742               554
# 2017-06                755               618
# 2017-07                722               630
# 2017-08                734               637
# 2017-09                816               634
# 2017-10                802               602
# 2017-11                818               632
# 2017-12                817               610
# 2018-01                831               657
# 2018-02                870               616
# 2018-03                846               590
# 2018-04                867               642
# 2018-05                833               660
# 2018-06                859               638
# 2018-07                910               638
# 2018-08                911               651
# 2018-09                948               614
# 2018-10                903               640
# 2018-11                905               661
# 2018-12                906               650
# 2019-01                868               665
# 2019-02                891               676
# 2019-03                876               647
# 2019-04                956               656
# 2019-05                945               647
# 2019-06                965               689
# 2019-07               1011               686
# 2019-08               1032               711
# 2019-09               1045               664
# 2019-10               1042               647
# 2019-11               1057               668
# 2019-12               1108               736
# 2020-01                992               725
# 2020-02               1087               669
# 2020-03               1011               692
# 2020-04               1061               718
# 2020-05               1077               695
# 2020-06               1113               755
# 2020-07               1120               733
# 2020-08               1197               743
# 2020-09               1172               835
# 2020-10               1225               743
# 2020-11               1269               827
# 2020-12               1307               802
# 2021-01               1252               829
# 2021-02               1287               846
# 2021-03               1187               843
# 2021-04               1222               920
# 2021-05               1291               884
# 2021-06               1244               897
# 2021-07               1437               941
# 2021-08               1293               861
# 2021-09               1341               819
# 2021-10               1377               834
# 2021-11               1228               825
# 2021-12               1364               847

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01      78
# 2017-02      72
# 2017-03      89
# 2017-04      69
# 2017-05      92
# 2017-06      56
# 2017-07      55
# 2017-08      39
# 2017-09      71
# 2017-10      61
# 2017-11      63
# 2017-12      63
# 2018-01      56
# 2018-02      59
# 2018-03      66
# 2018-04      69
# 2018-05      65
# 2018-06      55
# 2018-07      55
# 2018-08      68
# 2018-09      66
# 2018-10      60
# 2018-11      58
# 2018-12      56
# 2019-01      80
# 2019-02      71
# 2019-03      65
# 2019-04      58
# 2019-05      70
# 2019-06      57
# 2019-07      59
# 2019-08      70
# 2019-09      53
# 2019-10      76
# 2019-11      77
# 2019-12      47
# 2020-01      68
# 2020-02      62
# 2020-03      55
# 2020-04      57
# 2020-05      49
# 2020-06      65
# 2020-07      76
# 2020-08      58
# 2020-09      57
# 2020-10      61
# 2020-11      42
# 2020-12      40
# 2021-01      42
# 2021-02      56
# 2021-03      61
# 2021-04      46
# 2021-05      50
# 2021-06      43
# 2021-07      46
# 2021-08      49
# 2021-09      65
# 2021-10      69
# 2021-11      47
# 2021-12      50

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('중구')

plt.legend(loc="upper left")

plt.show()
