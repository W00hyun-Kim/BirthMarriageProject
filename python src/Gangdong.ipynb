# %%
import pandas as pd

# %%
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/강동구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴
# Out:
# (60, 5)

# %%
import matplotlib.pyplot as plt
plt.rc("font", family="Malgun Gothic")

# %%
import pandas as pd
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/강동구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/강동구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                732               484
# 2017-02                701               471
# 2017-03                698               415
# 2017-04                756               467
# 2017-05                715               465
# 2017-06                714               443
# 2017-07                768               516
# 2017-08                744               496
# 2017-09                770               509
# 2017-10                769               546
# 2017-11                816               557
# 2017-12                813               534
# 2018-01                830               562
# 2018-02                814               532
# 2018-03                826               543
# 2018-04                874               540
# 2018-05                819               537
# 2018-06                814               527
# 2018-07                867               551
# 2018-08                911               554
# 2018-09                915               549
# 2018-10                874               559
# 2018-11                874               581
# 2018-12                816               597
# 2019-01                984               584
# 2019-02                939               549
# 2019-03                869               400
# 2019-04                931               546
# 2019-05                976               508
# 2019-06               1003               521
# 2019-07                990               574
# 2019-08               1036               574
# 2019-09               1028               563
# 2019-10               1002               607
# 2019-11               1046               579
# 2019-12               1018               568
# 2020-01               1010               608
# 2020-02                999               607
# 2020-03               1005               621
# 2020-04                982               608
# 2020-05               1037               633
# 2020-06               1164               633
# 2020-07               1195               672
# 2020-08               1241               716
# 2020-09               1256               743
# 2020-10               1251               668
# 2020-11               1354               772
# 2020-12               1419               780
# 2021-01               1469               779
# 2021-02               1387               727
# 2021-03               1309               538
# 2021-04               1321               722
# 2021-05               1460               649
# 2021-06               1452               677
# 2021-07               1497               763
# 2021-08               1548               703
# 2021-09               1554               698
# 2021-10               1434               744
# 2021-11               1299               749
# 2021-12               1442               773

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     287
# 2017-02     285
# 2017-03     287
# 2017-04     262
# 2017-05     235
# 2017-06     255
# 2017-07     244
# 2017-08     244
# 2017-09     240
# 2017-10     209
# 2017-11     239
# 2017-12     181
# 2018-01     262
# 2018-02     218
# 2018-03     258
# 2018-04     242
# 2018-05     218
# 2018-06     215
# 2018-07     245
# 2018-08     211
# 2018-09     210
# 2018-10     212
# 2018-11     196
# 2018-12     172
# 2019-01     258
# 2019-02     182
# 2019-03     239
# 2019-04     195
# 2019-05     186
# 2019-06     204
# 2019-07     173
# 2019-08     228
# 2019-09     185
# 2019-10     219
# 2019-11     198
# 2019-12     170
# 2020-01     230
# 2020-02     201
# 2020-03     202
# 2020-04     207
# 2020-05     201
# 2020-06     224
# 2020-07     202
# 2020-08     232
# 2020-09     241
# 2020-10     207
# 2020-11     201
# 2020-12     187
# 2021-01     202
# 2021-02     230
# 2021-03     269
# 2021-04     240
# 2021-05     249
# 2021-06     256
# 2021-07     249
# 2021-08     258
# 2021-09     224
# 2021-10     229
# 2021-11     224
# 2021-12     205

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기

# %%
g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()

# %%
fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('강동구')

plt.legend(loc="upper left")

plt.show()
