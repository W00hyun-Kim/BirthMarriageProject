# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/용산구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/용산구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/용산구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                905               593
# 2017-02                928               559
# 2017-03                914               557
# 2017-04                939               576
# 2017-05                996               578
# 2017-06                988               573
# 2017-07               1008               566
# 2017-08                993               568
# 2017-09               1145               605
# 2017-10               1055               584
# 2017-11               1161               596
# 2017-12               1117               617
# 2018-01               1088               605
# 2018-02               1077               596
# 2018-03               1146               586
# 2018-04               1227               617
# 2018-05               1139               607
# 2018-06               1153               626
# 2018-07               1294               607
# 2018-08               1328               604
# 2018-09               1335               626
# 2018-10               1393               605
# 2018-11               1458               647
# 2018-12               1320               648
# 2019-01               1533               643
# 2019-02               1503               600
# 2019-03               1334               642
# 2019-04               1400               650
# 2019-05               1554               679
# 2019-06               1452               631
# 2019-07               1477               642
# 2019-08               1467               633
# 2019-09               1483               659
# 2019-10               1475               630
# 2019-11               1456               645
# 2019-12               1422               675
# 2020-01               1447               662
# 2020-02               1450               646
# 2020-03               1463               637
# 2020-04               1408               681
# 2020-05               1514               670
# 2020-06               1536               678
# 2020-07               1611               718
# 2020-08               1693               716
# 2020-09               1684               746
# 2020-10               1698               728
# 2020-11               1679               785
# 2020-12               1682               780
# 2021-01               1738               769
# 2021-02               1788               773
# 2021-03               1859               769
# 2021-04               1799               770
# 2021-05               1902               832
# 2021-06               1859               906
# 2021-07               1955               833
# 2021-08               1937               829
# 2021-09               2049               774
# 2021-10               2175               824
# 2021-11               2208               809
# 2021-12               2272               817

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     140
# 2017-02     116
# 2017-03     136
# 2017-04     130
# 2017-05     106
# 2017-06     117
# 2017-07     119
# 2017-08     131
# 2017-09     126
# 2017-10     115
# 2017-11     134
# 2017-12      94
# 2018-01     127
# 2018-02     124
# 2018-03     118
# 2018-04     122
# 2018-05     117
# 2018-06     121
# 2018-07     110
# 2018-08     100
# 2018-09     122
# 2018-10     115
# 2018-11     110
# 2018-12      91
# 2019-01     140
# 2019-02     102
# 2019-03     110
# 2019-04     118
# 2019-05     116
# 2019-06     104
# 2019-07     109
# 2019-08     105
# 2019-09      98
# 2019-10     110
# 2019-11     122
# 2019-12      80
# 2020-01     118
# 2020-02      90
# 2020-03     110
# 2020-04     103
# 2020-05     107
# 2020-06      93
# 2020-07      93
# 2020-08      87
# 2020-09     110
# 2020-10      91
# 2020-11      81
# 2020-12      93
# 2021-01     109
# 2021-02      99
# 2021-03     140
# 2021-04      99
# 2021-05     101
# 2021-06      94
# 2021-07     104
# 2021-08     101
# 2021-09     105
# 2021-10     108
# 2021-11      93
# 2021-12      95

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('용산구')

plt.legend(loc="upper left")

plt.show()
