# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/동작구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/동작구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/동작구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                698               553
# 2017-02                701               549
# 2017-03                721               530
# 2017-04                725               552
# 2017-05                723               532
# 2017-06                728               569
# 2017-07                752               554
# 2017-08                760               553
# 2017-09                767               572
# 2017-10                784               583
# 2017-11                783               575
# 2017-12                807               570
# 2018-01                817               585
# 2018-02                842               588
# 2018-03                838               575
# 2018-04                830               574
# 2018-05                837               590
# 2018-06                887               596
# 2018-07                907               589
# 2018-08                956               629
# 2018-09                978               621
# 2018-10                950               627
# 2018-11                952               603
# 2018-12                929               611
# 2019-01                891               609
# 2019-02                863               580
# 2019-03                866               583
# 2019-04                984               582
# 2019-05               1009               573
# 2019-06               1042               571
# 2019-07               1079               589
# 2019-08               1060               591
# 2019-09               1046               606
# 2019-10               1097               622
# 2019-11               1110               635
# 2019-12               1093               641
# 2020-01               1065               622
# 2020-02               1113               643
# 2020-03               1091               650
# 2020-04                989               651
# 2020-05               1127               655
# 2020-06               1177               658
# 2020-07               1243               686
# 2020-08               1267               686
# 2020-09               1275               722
# 2020-10               1313               712
# 2020-11               1393               753
# 2020-12               1473               749
# 2021-01               1392               725
# 2021-02               1436               728
# 2021-03               1334               741
# 2021-04               1449               779
# 2021-05               2738               841
# 2021-06               1423               799
# 2021-07               1511               805
# 2021-08               1550               806
# 2021-09               1477               767
# 2021-10               1512               790
# 2021-11               1542               795
# 2021-12               1380               813

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     261
# 2017-02     212
# 2017-03     268
# 2017-04     266
# 2017-05     227
# 2017-06     237
# 2017-07     219
# 2017-08     236
# 2017-09     263
# 2017-10     218
# 2017-11     212
# 2017-12     195
# 2018-01     220
# 2018-02     210
# 2018-03     221
# 2018-04     209
# 2018-05     235
# 2018-06     178
# 2018-07     213
# 2018-08     209
# 2018-09     177
# 2018-10     182
# 2018-11     185
# 2018-12     178
# 2019-01     204
# 2019-02     184
# 2019-03     201
# 2019-04     203
# 2019-05     188
# 2019-06     185
# 2019-07     196
# 2019-08     184
# 2019-09     189
# 2019-10     192
# 2019-11     155
# 2019-12     146
# 2020-01     221
# 2020-02     153
# 2020-03     193
# 2020-04     160
# 2020-05     180
# 2020-06     163
# 2020-07     163
# 2020-08     148
# 2020-09     204
# 2020-10     153
# 2020-11     153
# 2020-12     153
# 2021-01     170
# 2021-02     159
# 2021-03     164
# 2021-04     176
# 2021-05     147
# 2021-06     156
# 2021-07     147
# 2021-08     160
# 2021-09     137
# 2021-10     150
# 2021-11     151
# 2021-12     140

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('동작구')

plt.legend(loc="upper left")

plt.show()
