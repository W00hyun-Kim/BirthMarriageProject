# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/마포구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/마포구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/마포구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                774               576
# 2017-02                777               571
# 2017-03                779               575
# 2017-04                811               559
# 2017-05                832               581
# 2017-06                833               584
# 2017-07                856               591
# 2017-08                840               600
# 2017-09                863               588
# 2017-10                871               563
# 2017-11                877               614
# 2017-12                880               594
# 2018-01                920               635
# 2018-02                929               622
# 2018-03                924               604
# 2018-04                938               613
# 2018-05                960               617
# 2018-06                948               607
# 2018-07               1053               638
# 2018-08               1105               617
# ...

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     263
# 2017-02     265
# 2017-03     253
# 2017-04     270
# 2017-05     245
# 2017-06     213
# 2017-07     251
# 2017-08     189
# 2017-09     235
# 2017-10     203
# 2017-11     216
# 2017-12     209
# 2018-01     228
# 2018-02     213
# 2018-03     227
# 2018-04     197
# 2018-05     217
# 2018-06     198
# 2018-07     184
# 2018-08     221
# 2018-09     198
# 2018-10     218
# 2018-11     236
# 2018-12     191
# 2019-01     235
# 2019-02     207
# 2019-03     226
# 2019-04     203
# 2019-05     184
# 2019-06     180
# 2019-07     198
# 2019-08     191
# 2019-09     169
# 2019-10     212
# 2019-11     163
# 2019-12     166
# 2020-01     163
# 2020-02     172
# 2020-03     183
# 2020-04     178
# 2020-05     169
# 2020-06     154
# 2020-07     168
# 2020-08     183
# 2020-09     174
# 2020-10     166
# 2020-11     147
# 2020-12     158
# 2021-01     147
# 2021-02     176
# 2021-03     168
# 2021-04     167
# 2021-05     189
# 2021-06     154
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('마포구')

plt.legend(loc="upper left")

plt.show()
