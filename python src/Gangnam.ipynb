# %%
import pandas as pd

# %%
# %ls data
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 8487-D907
#
#  C:\Users\whKim\Desktop\PythonProject\Seoul-Apt\data 디렉터리
#
# 2022-05-06  오후 12:59    <DIR>          .
# 2022-05-06  오후 12:59    <DIR>          ..
# 2022-05-06  오후 12:59    <DIR>          .ipynb_checkpoints
# 2022-05-06  오후 04:46    <DIR>          플젝
#                0개 파일                   0 바이트
#                4개 디렉터리  15,139,241,984 바이트 남음

# %%
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/강남구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴
# Out:
# (60, 5)

# %%
import matplotlib.pyplot as plt
plt.rc("font", family="Malgun Gothic")

# %%
import pandas as pd
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/강남구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/강남구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01               1387               687
# 2017-02               1444               685
# 2017-03               1395               677
# 2017-04               1434               664
# 2017-05               1466               700
# 2017-06               1401               719
# 2017-07               1483               732
# 2017-08               1405               727
# 2017-09               1459               785
# 2017-10               1487               782
# 2017-11               1552               808
# 2017-12               1579               811
# 2018-01               1601               786
# 2018-02               1564               805
# 2018-03               1684               791
# 2018-04               1638               803
# 2018-05               1631               730
# 2018-06               1604               792
# 2018-07               1823               802
# 2018-08               1864               806
# 2018-09               1804               803
# 2018-10               1713               820
# 2018-11               1674               834
# 2018-12               1476               825
# 2019-01               1747               800
# 2019-02               1729               767
# 2019-03               1771               765
# 2019-04               1967               762
# 2019-05               2024               791
# 2019-06               2014               821
# 2019-07               2024               822
# 2019-08               2141               822
# 2019-09               2168               859
# 2019-10               2082               906
# 2019-11               2092               932
# 2019-12               2090               897
# 2020-01               1849               868
# 2020-02               2118               894
# 2020-03               1996               899
# 2020-04               2033               894
# 2020-05               1965               849
# 2020-06               2125               931
# 2020-07               2002               976
# 2020-08               2170               975
# 2020-09               2173               982
# 2020-10               2129              1034
# 2020-11               2257              1044
# 2020-12               2278              1080
# 2021-01               2271              1057
# 2021-02               2380              1003
# 2021-03               2130              1008
# 2021-04               2283               973
# 2021-05               2183              1037
# 2021-06               2398              1053
# 2021-07               2587              1070
# 2021-08               2382              1019
# 2021-09               2440              1107
# 2021-10               2575              1132
# 2021-11               2294              1120
# 2021-12               2499              1093

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     363
# 2017-02     277
# 2017-03     290
# 2017-04     272
# 2017-05     298
# 2017-06     269
# 2017-07     307
# 2017-08     290
# 2017-09     276
# 2017-10     293
# 2017-11     261
# 2017-12     260
# 2018-01     297
# 2018-02     219
# 2018-03     285
# 2018-04     266
# 2018-05     258
# 2018-06     242
# 2018-07     229
# 2018-08     251
# 2018-09     214
# 2018-10     231
# 2018-11     222
# 2018-12     226
# 2019-01     271
# 2019-02     219
# 2019-03     237
# 2019-04     265
# 2019-05     230
# 2019-06     223
# 2019-07     252
# 2019-08     215
# 2019-09     218
# 2019-10     211
# 2019-11     228
# 2019-12     180
# 2020-01     234
# 2020-02     181
# 2020-03     208
# 2020-04     213
# 2020-05     222
# 2020-06     206
# 2020-07     189
# 2020-08     179
# 2020-09     181
# 2020-10     193
# 2020-11     171
# 2020-12     179
# 2021-01     189
# 2021-02     182
# 2021-03     231
# 2021-04     196
# 2021-05     164
# 2021-06     188
# 2021-07     189
# 2021-08     190
# 2021-09     182
# 2021-10     185
# 2021-11     168
# 2021-12     189

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기

# %%
g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()

# %%
fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('강남구')

plt.legend(loc="upper left")

plt.show()
