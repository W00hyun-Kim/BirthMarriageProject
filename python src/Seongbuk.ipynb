# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/성북구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/성북구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/성북구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                533               456
# 2017-02                548               468
# 2017-03                557               449
# 2017-04                566               445
# 2017-05                545               449
# 2017-06                576               460
# 2017-07                589               454
# 2017-08                578               464
# 2017-09                593               455
# 2017-10                593               466
# 2017-11                602               468
# 2017-12                598               494
# 2018-01                606               496
# 2018-02                609               494
# 2018-03                610               489
# 2018-04                614               473
# 2018-05                616               480
# 2018-06                616               482
# 2018-07                641               489
# 2018-08                651               480
# 2018-09                672               492
# 2018-10                703               499
# 2018-11                659               487
# 2018-12                687               491
# 2019-01                679               515
# 2019-02                663               505
# 2019-03                703               499
# 2019-04                672               498
# 2019-05                724               481
# 2019-06                738               474
# 2019-07                770               483
# 2019-08                774               486
# 2019-09                775               479
# 2019-10                782               503
# 2019-11                810               516
# 2019-12                798               538
# 2020-01                773               537
# 2020-02                827               534
# 2020-03                810               530
# 2020-04                804               524
# 2020-05                811               526
# 2020-06                901               528
# 2020-07                983               583
# 2020-08               1019               586
# 2020-09               1017               600
# 2020-10               1001               592
# 2020-11               1056               637
# 2020-12               1095               643
# 2021-01               1103               649
# 2021-02               1080               631
# 2021-03               1121               666
# 2021-04               1094               626
# 2021-05               1107               638
# 2021-06               1145               641
# 2021-07               1149               639
# 2021-08               1230               620
# 2021-09               1270               600
# 2021-10               1209               633
# 2021-11               1168               628
# 2021-12               1143               649

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     275
# 2017-02     216
# 2017-03     248
# 2017-04     198
# 2017-05     213
# 2017-06     225
# 2017-07     216
# 2017-08     238
# 2017-09     239
# 2017-10     190
# 2017-11     202
# 2017-12     171
# 2018-01     228
# 2018-02     182
# 2018-03     212
# 2018-04     179
# 2018-05     210
# 2018-06     168
# 2018-07     193
# 2018-08     184
# 2018-09     164
# 2018-10     189
# 2018-11     186
# 2018-12     169
# 2019-01     217
# 2019-02     172
# 2019-03     173
# 2019-04     196
# 2019-05     172
# 2019-06     190
# 2019-07     177
# 2019-08     177
# 2019-09     174
# 2019-10     192
# 2019-11     160
# 2019-12     147
# 2020-01     195
# 2020-02     180
# 2020-03     190
# 2020-04     181
# 2020-05     173
# 2020-06     163
# 2020-07     153
# 2020-08     170
# 2020-09     162
# 2020-10     199
# 2020-11     154
# 2020-12     121
# 2021-01     152
# 2021-02     161
# 2021-03     179
# 2021-04     165
# 2021-05     183
# 2021-06     174
# 2021-07     175
# 2021-08     155
# 2021-09     165
# 2021-10     149
# 2021-11     141
# 2021-12     153

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('성북구')

plt.legend(loc="upper left")

plt.show()
