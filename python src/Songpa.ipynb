# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/송파구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/송파구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/송파구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                922               633
# 2017-02                948               604
# 2017-03                943               580
# 2017-04                982               581
# 2017-05               1019               620
# 2017-06                955               602
# 2017-07               1040               634
# 2017-08                978               640
# 2017-09               1124               668
# 2017-10               1091               662
# 2017-11               1141               679
# 2017-12               1108               684
# 2018-01               1140               674
# 2018-02               1128               621
# 2018-03               1120               637
# 2018-04               1079               647
# 2018-05               1115               642
# 2018-06               1167               655
# 2018-07               1393               685
# 2018-08               1277               679
# 2018-09               1302               694
# 2018-10               1087               692
# 2018-11               1119               693
# 2018-12               1169               705
# 2019-01               1269               692
# 2019-02               1311               669
# 2019-03               1489               681
# 2019-04               1403               629
# 2019-05               1449               680
# 2019-06               1426               698
# 2019-07               1426               710
# 2019-08               1421               698
# 2019-09               1455               695
# 2019-10               1428               719
# 2019-11               1497               755
# 2019-12               1456               734
# 2020-01               1385               726
# 2020-02               1484               712
# 2020-03               1382               715
# 2020-04               1590               744
# 2020-05               1608               790
# 2020-06               1668               790
# 2020-07               1477               790
# 2020-08               1548               806
# 2020-09               1576               824
# 2020-10               1550               797
# 2020-11               1688               864
# 2020-12               1837               871
# 2021-01               1860               888
# 2021-02               1917               837
# 2021-03               1902               868
# 2021-04               1941               795
# 2021-05               1880               885
# 2021-06               1980               876
# 2021-07               2065               869
# 2021-08               2100               852
# 2021-09               2208               881
# 2021-10               2050               899
# 2021-11               2210               912
# 2021-12               1854               833

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     488
# 2017-02     427
# 2017-03     471
# 2017-04     406
# 2017-05     410
# 2017-06     412
# 2017-07     403
# 2017-08     427
# 2017-09     437
# 2017-10     345
# 2017-11     375
# 2017-12     375
# 2018-01     440
# 2018-02     379
# 2018-03     404
# 2018-04     404
# 2018-05     396
# 2018-06     380
# 2018-07     364
# 2018-08     386
# 2018-09     361
# 2018-10     364
# 2018-11     359
# 2018-12     330
# 2019-01     402
# 2019-02     396
# 2019-03     422
# 2019-04     394
# 2019-05     380
# 2019-06     369
# 2019-07     399
# 2019-08     356
# 2019-09     332
# 2019-10     357
# 2019-11     332
# 2019-12     285
# 2020-01     342
# 2020-02     305
# 2020-03     328
# 2020-04     343
# 2020-05     326
# 2020-06     348
# 2020-07     296
# 2020-08     304
# 2020-09     316
# 2020-10     313
# 2020-11     273
# 2020-12     297
# 2021-01     282
# 2021-02     275
# 2021-03     346
# 2021-04     312
# 2021-05     300
# 2021-06     317
# 2021-07     300
# 2021-08     301
# 2021-09     286
# 2021-10     287
# 2021-11     292
# 2021-12     256

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('송파구')

plt.legend(loc="upper left")

plt.show()
