# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/종로구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/종로구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/종로구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                709               656
# 2017-02                682               597
# 2017-03                699               654
# 2017-04                673               670
# 2017-05                667               656
# 2017-06                697               646
# 2017-07                659               670
# 2017-08                691               629
# 2017-09                747               611
# 2017-10                713               586
# 2017-11                717               597
# 2017-12                738               629
# 2018-01                766               593
# 2018-02                738               556
# 2018-03                747               505
# 2018-04                707               497
# 2018-05                691               582
# 2018-06                761               574
# 2018-07                752               561
# 2018-08                815               569
# 2018-09                837               556
# 2018-10                749               547
# 2018-11                803               604
# 2018-12                702               632
# 2019-01                827               704
# 2019-02                929               729
# 2019-03                817               721
# 2019-04                886               753
# 2019-05                898               621
# 2019-06                974               692
# 2019-07               1185               705
# 2019-08               1015               678
# 2019-09               1067               642
# 2019-10               1062               673
# 2019-11               1055               701
# 2019-12               1024               696
# 2020-01                859               691
# 2020-02                889               633
# 2020-03                962               640
# 2020-04                858               618
# 2020-05               1028               636
# 2020-06               1068               630
# 2020-07               1068               727
# 2020-08               1288               687
# 2020-09               1040               671
# 2020-10                844               705
# 2020-11               1207               761
# 2020-12               1289               765
# 2021-01               1142               841
# 2021-02               1269               812
# 2021-03               1112               803
# 2021-04               1221               746
# 2021-05               1209               848
# 2021-06               1139               845
# 2021-07               1303               848
# 2021-08               1323               834
# 2021-09               1272               794
# 2021-10               1378               877
# 2021-11               1183               774
# 2021-12               1390               799

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01      75
# 2017-02      45
# 2017-03      53
# 2017-04      54
# 2017-05      54
# 2017-06      60
# 2017-07      59
# 2017-08      66
# 2017-09      52
# 2017-10      58
# 2017-11      53
# 2017-12      60
# 2018-01      65
# 2018-02      47
# 2018-03      60
# 2018-04      51
# 2018-05      50
# 2018-06      49
# 2018-07      40
# 2018-08      61
# 2018-09      56
# 2018-10      61
# 2018-11      65
# 2018-12      39
# 2019-01      55
# 2019-02      48
# 2019-03      64
# 2019-04      57
# 2019-05      54
# 2019-06      56
# 2019-07      62
# 2019-08      49
# 2019-09      64
# 2019-10      59
# 2019-11      60
# 2019-12      45
# 2020-01      60
# 2020-02      47
# 2020-03      40
# 2020-04      48
# 2020-05      51
# 2020-06      40
# 2020-07      38
# 2020-08      48
# 2020-09      50
# 2020-10      45
# 2020-11      33
# 2020-12      29
# 2021-01      48
# 2021-02      48
# 2021-03      49
# 2021-04      54
# 2021-05      48
# 2021-06      50
# 2021-07      55
# 2021-08      38
# 2021-09      33
# 2021-10      42
# 2021-11      40
# 2021-12      33

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('종로구')

plt.legend(loc="upper left")

plt.show()
