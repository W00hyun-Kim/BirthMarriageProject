# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/영등포구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/영등포구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/영등포구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                633               497
# 2017-02                660               518
# 2017-03                700               510
# 2017-04                687               502
# 2017-05                694               496
# 2017-06                705               504
# 2017-07                714               513
# 2017-08                701               496
# 2017-09                743               518
# 2017-10                746               518
# 2017-11                775               526
# 2017-12                797               529
# 2018-01                820               519
# 2018-02                788               522
# 2018-03                780               522
# 2018-04                810               531
# 2018-05                829               531
# 2018-06                835               521
# 2018-07                901               528
# 2018-08                898               541
# 2018-09                960               530
# 2018-10                920               557
# 2018-11                887               561
# 2018-12                878               560
# 2019-01                903               549
# 2019-02                895               526
# 2019-03                919               561
# 2019-04               1017               538
# 2019-05               1003               569
# 2019-06               1099               615
# 2019-07               1026               551
# 2019-08               1003               570
# 2019-09               1042               567
# 2019-10               1072               584
# 2019-11               1053               593
# 2019-12               1044               593
# 2020-01               1038               599
# 2020-02               1064               608
# 2020-03               1088               590
# 2020-04               1076               604
# 2020-05               1117               620
# 2020-06               1212               607
# 2020-07               1170               605
# 2020-08               1217               640
# 2020-09               1216               644
# 2020-10               1222               697
# 2020-11               1307               689
# 2020-12               1333               692
# 2021-01               1357               711
# 2021-02               1385               653
# 2021-03               1415               663
# 2021-04               1412               662
# 2021-05               1309               712
# 2021-06               1336               721
# 2021-07               1421               718
# 2021-08               1430               667
# 2021-09               1418               697
# 2021-10               1401               749
# 2021-11               1241               743
# 2021-12               1327               733

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     265
# 2017-02     222
# 2017-03     260
# 2017-04     242
# 2017-05     228
# 2017-06     236
# 2017-07     231
# 2017-08     226
# 2017-09     248
# 2017-10     213
# 2017-11     206
# 2017-12     228
# 2018-01     265
# 2018-02     214
# 2018-03     259
# 2018-04     236
# 2018-05     240
# 2018-06     218
# 2018-07     195
# 2018-08     205
# 2018-09     228
# 2018-10     228
# 2018-11     197
# 2018-12     213
# 2019-01     262
# 2019-02     257
# 2019-03     237
# 2019-04     203
# 2019-05     225
# 2019-06     221
# 2019-07     211
# 2019-08     204
# 2019-09     218
# 2019-10     203
# 2019-11     206
# 2019-12     186
# 2020-01     236
# 2020-02     184
# 2020-03     186
# 2020-04     193
# 2020-05     193
# 2020-06     161
# 2020-07     200
# 2020-08     191
# 2020-09     212
# 2020-10     201
# 2020-11     147
# 2020-12     192
# 2021-01     220
# 2021-02     230
# 2021-03     200
# 2021-04     204
# 2021-05     208
# 2021-06     216
# 2021-07     201
# 2021-08     191
# 2021-09     201
# 2021-10     198
# 2021-11     177
# 2021-12     177

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('영등포구')

plt.legend(loc="upper left")

plt.show()
