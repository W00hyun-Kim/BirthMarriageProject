# %%
import pandas as pd

# %%
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/강서구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴
# Out:
# (60, 5)

# %%
import matplotlib.pyplot as plt
plt.rc("font", family="Malgun Gothic")

# %%
import pandas as pd
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/강서구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/강서구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                579               437
# 2017-02                601               430
# 2017-03                609               443
# 2017-04                617               438
# 2017-05                650               445
# 2017-06                646               457
# 2017-07                662               473
# 2017-08                635               471
# 2017-09                674               478
# 2017-10                696               453
# 2017-11                711               434
# 2017-12                706               465
# 2018-01                711               490
# 2018-02                717               493
# 2018-03                686               466
# 2018-04                692               475
# 2018-05                710               464
# 2018-06                715               481
# 2018-07                747               429
# 2018-08                766               438
# 2018-09                789               484
# 2018-10                755               481
# 2018-11                730               477
# 2018-12                685               488
# 2019-01                742               510
# 2019-02                748               486
# 2019-03                740               497
# 2019-04                745               507
# 2019-05                790               519
# 2019-06                814               520
# 2019-07                879               515
# 2019-08                831               544
# 2019-09                820               533
# 2019-10                883               502
# 2019-11                904               504
# 2019-12                894               519
# 2020-01                857               543
# 2020-02                901               546
# 2020-03                862               563
# 2020-04                793               543
# 2020-05                907               554
# 2020-06                953               556
# 2020-07                979               473
# 2020-08               1018               456
# 2020-09               1033               544
# 2020-10               1027               531
# 2020-11               1036               537
# 2020-12               1091               620
# 2021-01               1165               615
# 2021-02               1064               578
# 2021-03               1052               642
# 2021-04               1130               613
# 2021-05               1173               637
# 2021-06               1238               625
# 2021-07               1245               654
# 2021-08               1253               621
# 2021-09               1235               651
# 2021-10               1228               611
# 2021-11               1054               584
# 2021-12               1114               634

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     423
# 2017-02     396
# 2017-03     438
# 2017-04     410
# 2017-05     455
# 2017-06     368
# 2017-07     399
# 2017-08     415
# 2017-09     399
# 2017-10     371
# 2017-11     384
# 2017-12     342
# 2018-01     446
# 2018-02     361
# 2018-03     394
# 2018-04     382
# 2018-05     359
# 2018-06     312
# 2018-07     333
# 2018-08     363
# 2018-09     345
# 2018-10     332
# 2018-11     339
# 2018-12     294
# 2019-01     374
# 2019-02     312
# 2019-03     347
# 2019-04     350
# 2019-05     333
# 2019-06     305
# 2019-07     303
# 2019-08     323
# 2019-09     302
# 2019-10     313
# 2019-11     328
# 2019-12     251
# 2020-01     365
# 2020-02     271
# 2020-03     325
# 2020-04     314
# 2020-05     297
# 2020-06     248
# 2020-07     307
# 2020-08     284
# 2020-09     265
# 2020-10     245
# 2020-11     227
# 2020-12     197
# 2021-01     237
# 2021-02     249
# 2021-03     311
# 2021-04     275
# 2021-05     273
# 2021-06     282
# 2021-07     269
# 2021-08     248
# 2021-09     218
# 2021-10     205
# 2021-11     241
# 2021-12     203

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기

# %%
g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()

# %%
fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('강서구')

plt.legend(loc="upper left")

plt.show()
