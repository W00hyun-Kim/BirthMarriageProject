# %%
import pandas as pd

# %%
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/관악구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴
# Out:
# (60, 5)

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/관악구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/관악구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                630               450
# 2017-02                558               439
# 2017-03                532               432
# 2017-04                533               439
# 2017-05                552               448
# 2017-06                548               463
# 2017-07                582               464
# 2017-08                583               466
# 2017-09                600               457
# 2017-10                591               508
# 2017-11                589               467
# 2017-12                612               450
# 2018-01                622               494
# 2018-02                616               475
# 2018-03                632               479
# 2018-04                616               462
# 2018-05                627               470
# 2018-06                651               479
# 2018-07                636               497
# 2018-08                642               492
# 2018-09                685               501
# 2018-10                718               488
# 2018-11                716               495
# 2018-12                715               488
# 2019-01                672               504
# 2019-02                705               483
# 2019-03                691               464
# 2019-04                693               470
# 2019-05                683               477
# 2019-06                757               482
# 2019-07                772               487
# 2019-08                771               503
# 2019-09                749               474
# 2019-10                788               511
# 2019-11                783               499
# 2019-12                787               510
# 2020-01                799               511
# 2020-02                804               535
# 2020-03                796               537
# 2020-04                768               521
# 2020-05                803               519
# 2020-06                875               543
# 2020-07                860               549
# 2020-08                938               557
# 2020-09                931               564
# 2020-10                923               578
# 2020-11               1000               597
# 2020-12               1020               603
# 2021-01               1026               607
# 2021-02               1057               596
# 2021-03               1052               626
# 2021-04                996               607
# 2021-05               1111               640
# 2021-06               1097               670
# 2021-07               1136               666
# 2021-08               1142               633
# 2021-09               1160               557
# 2021-10               1096               666
# 2021-11               1106               613
# 2021-12               1099               648

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     280
# 2017-02     274
# 2017-03     282
# 2017-04     247
# 2017-05     247
# 2017-06     272
# 2017-07     244
# 2017-08     235
# 2017-09     248
# 2017-10     195
# 2017-11     200
# 2017-12     207
# 2018-01     261
# 2018-02     218
# 2018-03     215
# 2018-04     221
# 2018-05     209
# 2018-06     223
# 2018-07     251
# 2018-08     225
# 2018-09     207
# 2018-10     194
# 2018-11     187
# 2018-12     171
# 2019-01     209
# 2019-02     204
# 2019-03     193
# 2019-04     185
# 2019-05     214
# 2019-06     174
# 2019-07     206
# 2019-08     165
# 2019-09     190
# 2019-10     169
# 2019-11     179
# 2019-12     157
# 2020-01     172
# 2020-02     195
# 2020-03     174
# 2020-04     166
# 2020-05     151
# 2020-06     143
# 2020-07     156
# 2020-08     177
# 2020-09     156
# 2020-10     155
# 2020-11     132
# 2020-12     128
# 2021-01     133
# 2021-02     131
# 2021-03     167
# 2021-04     120
# 2021-05     174
# 2021-06     160
# 2021-07     134
# 2021-08     123
# 2021-09     152
# 2021-10     138
# 2021-11     135
# 2021-12     128

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기

# %%
g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()

# %%
fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('관악구')

plt.legend(loc="upper left")

plt.show()
