# %%
import pandas as pd

# %%
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/광진구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴
# Out:
# (60, 5)

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/광진구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/광진구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                695               584
# 2017-02                703               565
# 2017-03                730               562
# 2017-04                777               559
# 2017-05                753               584
# 2017-06                763               579
# 2017-07                807               575
# 2017-08                795               581
# 2017-09                791               608
# 2017-10                845               603
# 2017-11                870               642
# 2017-12                874               628
# 2018-01                874               626
# 2018-02                891               594
# 2018-03                885               612
# 2018-04                872               622
# 2018-05                838               616
# 2018-06                869               599
# 2018-07                953               618
# 2018-08               1037               662
# 2018-09               1065               646
# 2018-10               1006               659
# 2018-11               1018               652
# 2018-12                905               616
# 2019-01                846               607
# 2019-02                951               605
# 2019-03                926               600
# 2019-04                997               621
# 2019-05               1029               628
# 2019-06               1066               613
# 2019-07               1102               621
# 2019-08               1119               640
# 2019-09               1103               652
# 2019-10               1163               658
# 2019-11               1189               676
# 2019-12               1167               668
# 2020-01               1135               662
# 2020-02               1149               683
# 2020-03               1104               648
# 2020-04               1077               645
# 2020-05               1095               670
# 2020-06               1294               699
# 2020-07               1305               726
# 2020-08               1421               783
# 2020-09               1360               730
# 2020-10               1309               751
# 2020-11               1408               764
# 2020-12               1487               779
# 2021-01               1567               756
# 2021-02               1464               756
# 2021-03               1407               765
# 2021-04               1411               787
# 2021-05               1486               770
# 2021-06               1521               803
# 2021-07               1535               818
# 2021-08               1622               812
# 2021-09               1526               867
# 2021-10               1548               874
# 2021-11               1521               840
# 2021-12               1596               848

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     249
# 2017-02     220
# 2017-03     221
# 2017-04     200
# 2017-05     191
# 2017-06     183
# 2017-07     194
# 2017-08     191
# 2017-09     184
# 2017-10     175
# 2017-11     162
# 2017-12     177
# 2018-01     206
# 2018-02     195
# 2018-03     198
# 2018-04     176
# 2018-05     186
# 2018-06     182
# 2018-07     212
# 2018-08     175
# 2018-09     187
# 2018-10     163
# 2018-11     171
# 2018-12     146
# 2019-01     196
# 2019-02     209
# 2019-03     158
# 2019-04     161
# 2019-05     156
# 2019-06     148
# 2019-07     161
# 2019-08     165
# 2019-09     169
# 2019-10     160
# 2019-11     155
# 2019-12     119
# 2020-01     139
# 2020-02     119
# 2020-03     148
# 2020-04     134
# 2020-05     121
# 2020-06     122
# 2020-07     135
# 2020-08     140
# 2020-09     128
# 2020-10     115
# 2020-11     121
# 2020-12     110
# 2021-01     122
# 2021-02     109
# 2021-03     151
# 2021-04     145
# 2021-05     126
# 2021-06     144
# 2021-07     135
# 2021-08     131
# 2021-09     116
# 2021-10     121
# 2021-11     111
# 2021-12      99

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('광진구')

plt.legend(loc="upper left")

plt.show()
