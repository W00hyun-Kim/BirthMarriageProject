# %%
import pandas as pd

# %%
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/강북구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴
# Out:
# (60, 5)

# %%
import matplotlib.pyplot as plt
plt.rc("font", family="Malgun Gothic")

# %%
import pandas as pd
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/강북구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/강북구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                479               382
# 2017-02                497               379
# 2017-03                478               379
# 2017-04                504               383
# 2017-05                482               382
# 2017-06                528               391
# 2017-07                521               379
# 2017-08                508               392
# 2017-09                533               367
# 2017-10                542               371
# 2017-11                526               396
# 2017-12                587               417
# 2018-01                540               387
# 2018-02                552               411
# 2018-03                550               403
# 2018-04                555               393
# 2018-05                549               391
# 2018-06                568               423
# 2018-07                562               366
# 2018-08                571               396
# 2018-09                581               412
# 2018-10                597               429
# 2018-11                618               406
# 2018-12                581               425
# 2019-01                561               416
# 2019-02                630               398
# 2019-03                577               400
# 2019-04                597               398
# 2019-05                608               408
# 2019-06                596               410
# 2019-07                614               405
# 2019-08                638               408
# 2019-09                720               403
# 2019-10                728               405
# 2019-11                718               417
# 2019-12                679               446
# 2020-01                696               412
# 2020-02                675               430
# 2020-03                692               477
# 2020-04                654               484
# 2020-05                712               474
# 2020-06                793               462
# 2020-07                796               434
# 2020-08                825               505
# 2020-09                854               529
# 2020-10                889               507
# 2020-11                885               519
# 2020-12                938               589
# 2021-01                924               541
# 2021-02                871               510
# 2021-03                958               542
# 2021-04                907               500
# 2021-05                964               524
# 2021-06                952               517
# 2021-07                981               532
# 2021-08                967               566
# 2021-09                918               512
# 2021-10               1069               528
# 2021-11                870               517
# 2021-12                774               568

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     154
# 2017-02     158
# 2017-03     181
# 2017-04     167
# 2017-05     154
# 2017-06     159
# 2017-07     145
# 2017-08     141
# 2017-09     138
# 2017-10     129
# 2017-11     116
# 2017-12     130
# 2018-01     143
# 2018-02     105
# 2018-03     130
# 2018-04     122
# 2018-05     112
# 2018-06     112
# 2018-07     114
# 2018-08     112
# 2018-09     101
# 2018-10     116
# 2018-11      92
# 2018-12      85
# 2019-01     126
# 2019-02     118
# 2019-03     122
# 2019-04     106
# 2019-05     114
# 2019-06      70
# 2019-07     122
# 2019-08      99
# 2019-09      86
# 2019-10      98
# 2019-11      88
# 2019-12      78
# 2020-01     120
# 2020-02      83
# 2020-03     101
# 2020-04      90
# 2020-05      94
# 2020-06      98
# 2020-07      92
# 2020-08      79
# 2020-09      76
# 2020-10      67
# 2020-11      73
# 2020-12      76
# 2021-01      81
# 2021-02      99
# 2021-03      85
# 2021-04      83
# 2021-05      91
# 2021-06      90
# 2021-07      93
# 2021-08      68
# 2021-09      86
# 2021-10      84
# 2021-11      69
# 2021-12      84

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기

# %%
g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()

# %%
fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('강북구')

plt.legend(loc="upper left")

plt.show()
