# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/양천구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/양천구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/양천구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                599               536
# 2017-02                631               518
# 2017-03                661               506
# 2017-04                739               497
# 2017-05                805               505
# 2017-06                762               477
# 2017-07                806               533
# 2017-08                678               429
# 2017-09                738               501
# 2017-10                810               483
# 2017-11                914               555
# 2017-12                838               549
# 2018-01                795               534
# 2018-02                720               536
# 2018-03                664               532
# 2018-04                668               505
# 2018-05                714               536
# 2018-06                776               543
# 2018-07                929               542
# 2018-08                951               548
# 2018-09                827               574
# 2018-10                785               555
# 2018-11                781               590
# 2018-12                747               595
# 2019-01                850               566
# 2019-02                825               554
# 2019-03                876               529
# 2019-04                939               521
# 2019-05               1058               537
# 2019-06               1149               507
# 2019-07               1027               555
# 2019-08                946               465
# 2019-09               1041               534
# 2019-10               1079               557
# 2019-11               1086               592
# 2019-12               1011               607
# 2020-01                917               579
# 2020-02                905               574
# 2020-03                906               540
# 2020-04               1011               533
# 2020-05               1053               566
# 2020-06               1144               591
# 2020-07               1224               606
# 2020-08               1230               602
# 2020-09               1087               631
# 2020-10               1187               630
# 2020-11               1376               684
# 2020-12               1433               708
# 2021-01               1393               679
# 2021-02               1433               671
# 2021-03               1351               662
# 2021-04               1610               647
# 2021-05               1139               694
# 2021-06               1318               624
# 2021-07               1240               679
# 2021-08               1360               553
# 2021-09               1303               630
# 2021-10               1343               663
# 2021-11               1233               745
# 2021-12               1421               733

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     276
# 2017-02     296
# 2017-03     296
# 2017-04     241
# 2017-05     221
# 2017-06     226
# 2017-07     255
# 2017-08     244
# 2017-09     210
# 2017-10     220
# 2017-11     213
# 2017-12     178
# 2018-01     218
# 2018-02     208
# 2018-03     196
# 2018-04     187
# 2018-05     235
# 2018-06     193
# 2018-07     181
# 2018-08     196
# 2018-09     202
# 2018-10     197
# 2018-11     194
# 2018-12     180
# 2019-01     210
# 2019-02     203
# 2019-03     226
# 2019-04     209
# 2019-05     191
# 2019-06     153
# 2019-07     190
# 2019-08     174
# 2019-09     171
# 2019-10     193
# 2019-11     150
# 2019-12     152
# 2020-01     164
# 2020-02     148
# 2020-03     153
# 2020-04     160
# 2020-05     153
# 2020-06     142
# 2020-07     166
# 2020-08     167
# 2020-09     175
# 2020-10     156
# 2020-11     163
# 2020-12     128
# 2021-01     164
# 2021-02     153
# 2021-03     163
# 2021-04     170
# 2021-05     169
# 2021-06     163
# 2021-07     148
# 2021-08     155
# 2021-09     137
# 2021-10     153
# 2021-11     148
# 2021-12     131

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('양천구')

plt.legend(loc="upper left")

plt.show()
