# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/도봉구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/도봉구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/도봉구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                439               335
# 2017-02                446               341
# 2017-03                448               334
# 2017-04                459               333
# 2017-05                469               333
# 2017-06                475               338
# 2017-07                479               351
# 2017-08                455               345
# 2017-09                471               346
# 2017-10                478               348
# 2017-11                486               350
# 2017-12                497               346
# 2018-01                486               369
# 2018-02                505               378
# 2018-03                492               356
# 2018-04                479               346
# 2018-05                498               347
# 2018-06                514               342
# 2018-07                517               346
# 2018-08                501               359
# 2018-09                514               348
# 2018-10                534               340
# 2018-11                515               344
# 2018-12                535               357
# 2019-01                527               351
# 2019-02                544               346
# 2019-03                525               344
# 2019-04                545               342
# 2019-05                548               344
# 2019-06                582               350
# 2019-07                591               344
# 2019-08                575               356
# 2019-09                601               354
# 2019-10                600               356
# 2019-11                631               363
# 2019-12                639               362
# 2020-01                640               370
# 2020-02                631               367
# 2020-03                605               362
# 2020-04                607               359
# 2020-05                596               368
# 2020-06                628               375
# 2020-07                683               380
# 2020-08                724               385
# 2020-09                748               412
# 2020-10                737               408
# 2020-11                811               425
# 2020-12                831               438
# 2021-01                850               441
# 2021-02                826               436
# 2021-03                883               430
# 2021-04                907               457
# 2021-05                910               462
# 2021-06                887               484
# 2021-07                893               469
# 2021-08                990               443
# 2021-09                953               460
# 2021-10                944               441
# 2021-11                993               464
# 2021-12               1015               454

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     178
# 2017-02     170
# 2017-03     187
# 2017-04     157
# 2017-05     159
# 2017-06     160
# 2017-07     141
# 2017-08     177
# 2017-09     148
# 2017-10     152
# 2017-11     126
# 2017-12     151
# 2018-01     160
# 2018-02     131
# 2018-03     136
# 2018-04     153
# 2018-05     132
# 2018-06     142
# 2018-07     140
# 2018-08     157
# 2018-09     129
# 2018-10     141
# 2018-11     150
# 2018-12     136
# 2019-01     130
# 2019-02     124
# 2019-03     117
# 2019-04     137
# 2019-05      99
# 2019-06     151
# 2019-07     105
# 2019-08     133
# 2019-09     124
# 2019-10     148
# 2019-11     111
# 2019-12     104
# 2020-01     121
# 2020-02      98
# 2020-03     111
# 2020-04     110
# 2020-05     113
# 2020-06     110
# 2020-07      94
# 2020-08      92
# 2020-09     108
# 2020-10      92
# 2020-11      80
# 2020-12      89
# 2021-01      83
# 2021-02      83
# 2021-03     101
# 2021-04      93
# 2021-05     116
# 2021-06      92
# 2021-07     109
# 2021-08     103
# 2021-09     109
# 2021-10      82
# 2021-11      98
# 2021-12      72

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('도봉구')

plt.legend(loc="upper left")

plt.show()
