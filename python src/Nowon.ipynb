# %%
import pandas as pd
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/노원구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴
# Out:
# (60, 5)

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/노원구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/노원구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                504               370
# 2017-02                510               367
# 2017-03                513               366
# 2017-04                517               363
# 2017-05                532               362
# 2017-06                540               369
# 2017-07                553               376
# 2017-08                548               380
# 2017-09                557               368
# 2017-10                559               374
# 2017-11                573               377
# 2017-12                588               387
# 2018-01                582               385
# 2018-02                589               379
# 2018-03                578               379
# 2018-04                579               369
# 2018-05                568               363
# 2018-06                579               372
# 2018-07                604               369
# 2018-08                607               374
# 2018-09                635               381
# 2018-10                662               387
# 2018-11                643               392
# 2018-12                656               393
# 2019-01                618               382
# 2019-02                650               381
# 2019-03                632               368
# 2019-04                650               369
# 2019-05                676               371
# 2019-06                700               377
# 2019-07                680               379
# 2019-08                691               382
# 2019-09                691               389
# 2019-10                709               392
# 2019-11                740               410
# 2019-12                754               408
# 2020-01                757               404
# 2020-02                755               403
# 2020-03                759               395
# 2020-04                738               391
# 2020-05                776               391
# 2020-06                804               402
# 2020-07                877               408
# 2020-08                899               418
# 2020-09                947               443
# 2020-10                944               452
# 2020-11               1001               464
# 2020-12               1036               487
# 2021-01               1045               469
# 2021-02               1038               477
# 2021-03               1074               467
# 2021-04               1123               464
# 2021-05               1118               470
# 2021-06               1125               477
# 2021-07               1148               489
# 2021-08               1170               487
# 2021-09               1221               482
# 2021-10               1191               484
# 2021-11               1232               497
# 2021-12               1172               501

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     358
# 2017-02     289
# 2017-03     316
# 2017-04     258
# 2017-05     281
# 2017-06     300
# 2017-07     283
# 2017-08     312
# 2017-09     304
# 2017-10     288
# 2017-11     254
# 2017-12     251
# 2018-01     298
# 2018-02     267
# 2018-03     255
# 2018-04     248
# 2018-05     230
# 2018-06     212
# 2018-07     242
# 2018-08     225
# 2018-09     201
# 2018-10     256
# 2018-11     214
# 2018-12     203
# 2019-01     256
# 2019-02     203
# 2019-03     233
# 2019-04     225
# 2019-05     219
# 2019-06     191
# 2019-07     244
# 2019-08     201
# 2019-09     215
# 2019-10     229
# 2019-11     201
# 2019-12     187
# 2020-01     231
# 2020-02     192
# 2020-03     199
# 2020-04     190
# 2020-05     187
# 2020-06     173
# 2020-07     192
# 2020-08     180
# 2020-09     179
# 2020-10     187
# 2020-11     165
# 2020-12     177
# 2021-01     171
# 2021-02     173
# 2021-03     230
# 2021-04     197
# 2021-05     169
# 2021-06     179
# 2021-07     241
# 2021-08     187
# 2021-09     180
# 2021-10     167
# 2021-11     167
# 2021-12     170

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('노원구')

plt.legend(loc="upper left")

plt.show()
