# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/은평구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/은평구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/은평구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                565               359
# 2017-02                529               373
# 2017-03                530               367
# 2017-04                541               403
# 2017-05                551               413
# 2017-06                558               436
# 2017-07                573               466
# 2017-08                553               457
# 2017-09                578               449
# 2017-10                587               466
# 2017-11                611               454
# 2017-12                610               440
# 2018-01                632               431
# 2018-02                619               416
# 2018-03                630               434
# 2018-04                610               391
# 2018-05                635               447
# 2018-06                623               450
# 2018-07                622               356
# 2018-08                631               421
# 2018-09                636               396
# 2018-10                621               460
# 2018-11                636               469
# 2018-12                622               489
# 2019-01                645               465
# 2019-02                669               447
# 2019-03                649               442
# 2019-04                650               462
# 2019-05                679               467
# 2019-06                660               469
# 2019-07                676               476
# 2019-08                731               477
# 2019-09                762               460
# 2019-10                774               486
# 2019-11                773               507
# 2019-12                779               490
# 2020-01                773               517
# 2020-02                751               475
# 2020-03                732               516
# 2020-04                709               489
# 2020-05                745               550
# 2020-06                838               553
# 2020-07                840               513
# 2020-08                875               532
# 2020-09                838               439
# 2020-10                888               587
# 2020-11                970               584
# 2020-12                980               582
# 2021-01               1032               564
# 2021-02                957               518
# 2021-03                957               550
# 2021-04                901               557
# 2021-05               1000               592
# 2021-06               1025               573
# 2021-07               1101               653
# 2021-08               1119               587
# 2021-09               1146               530
# 2021-10               1126               572
# 2021-11               1093               594
# 2021-12               1174               626

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     296
# 2017-02     249
# 2017-03     298
# 2017-04     236
# 2017-05     229
# 2017-06     248
# 2017-07     219
# 2017-08     237
# 2017-09     260
# 2017-10     228
# 2017-11     219
# 2017-12     211
# 2018-01     266
# 2018-02     201
# 2018-03     246
# 2018-04     240
# 2018-05     222
# 2018-06     205
# 2018-07     239
# 2018-08     268
# 2018-09     224
# 2018-10     204
# 2018-11     205
# 2018-12     183
# 2019-01     246
# 2019-02     218
# 2019-03     205
# 2019-04     218
# 2019-05     223
# 2019-06     210
# 2019-07     200
# 2019-08     188
# 2019-09     195
# 2019-10     180
# 2019-11     170
# 2019-12     154
# 2020-01     200
# 2020-02     198
# 2020-03     194
# 2020-04     186
# 2020-05     178
# 2020-06     161
# 2020-07     166
# 2020-08     175
# 2020-09     194
# 2020-10     164
# 2020-11     163
# 2020-12     165
# 2021-01     179
# 2021-02     164
# 2021-03     209
# 2021-04     198
# 2021-05     186
# 2021-06     186
# 2021-07     155
# 2021-08     161
# 2021-09     177
# 2021-10     149
# 2021-11     159
# 2021-12     153

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('은평구')

plt.legend(loc="upper left")

plt.show()
