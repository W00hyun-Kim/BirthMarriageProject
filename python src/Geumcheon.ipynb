# %%
import pandas as pd

# %%
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/금천구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴
# Out:
# (60, 5)

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/금천구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/금천구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                470               338
# 2017-02                466               327
# 2017-03                468               322
# 2017-04                477               347
# 2017-05                462               333
# 2017-06                456               351
# 2017-07                465               355
# 2017-08                480               351
# 2017-09                506               378
# 2017-10                460               382
# 2017-11                498               384
# 2017-12                527               374
# 2018-01                498               360
# 2018-02                496               405
# 2018-03                506               399
# 2018-04                532               346
# 2018-05                493               359
# 2018-06                529               380
# 2018-07                523               383
# 2018-08                522               436
# 2018-09                497               446
# 2018-10                528               461
# 2018-11                537               449
# 2018-12                587               464
# 2019-01                550               428
# 2019-02                511               396
# 2019-03                544               379
# 2019-04                522               375
# 2019-05                649               439
# 2019-06                615               493
# 2019-07                615               410
# 2019-08                668               407
# 2019-09                635               394
# 2019-10                627               430
# 2019-11                641               420
# 2019-12                646               432
# 2020-01                663               473
# 2020-02                647               436
# 2020-03                671               411
# 2020-04                621               414
# 2020-05                637               439
# 2020-06                676               457
# 2020-07                757               459
# 2020-08                816               486
# 2020-09                809               527
# 2020-10                729               579
# 2020-11                878               659
# 2020-12                890               623
# 2021-01                894               605
# 2021-02                887               596
# 2021-03                857               546
# 2021-04                872               571
# 2021-05                876               554
# 2021-06                934               572
# 2021-07                947               560
# 2021-08                924               630
# 2021-09                994               580
# 2021-10               1043               563
# 2021-11                886               590
# 2021-12                898               572

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     131
# 2017-02     118
# 2017-03     148
# 2017-04     105
# 2017-05     121
# 2017-06     107
# 2017-07     128
# 2017-08     133
# 2017-09     133
# 2017-10     142
# 2017-11     121
# 2017-12     111
# 2018-01     134
# 2018-02     123
# 2018-03     118
# 2018-04      91
# 2018-05     115
# 2018-06     110
# 2018-07      98
# 2018-08     130
# 2018-09      96
# 2018-10     101
# 2018-11     125
# 2018-12      73
# 2019-01     130
# 2019-02     102
# 2019-03     108
# 2019-04      95
# 2019-05      91
# 2019-06      86
# 2019-07      95
# 2019-08      97
# 2019-09      88
# 2019-10      93
# 2019-11      90
# 2019-12      79
# 2020-01     117
# 2020-02      87
# 2020-03      74
# 2020-04      99
# 2020-05      68
# 2020-06      85
# 2020-07     104
# 2020-08     102
# 2020-09     104
# 2020-10      92
# 2020-11      88
# 2020-12      72
# 2021-01      93
# 2021-02      82
# 2021-03      93
# 2021-04      83
# 2021-05      73
# 2021-06     109
# 2021-07      87
# 2021-08      90
# 2021-09      86
# 2021-10      67
# 2021-11      76
# 2021-12      85

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('금천구')

plt.legend(loc="upper left")

plt.show()
