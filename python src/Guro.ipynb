# %%
import pandas as pd

# %%
df_last = pd.read_csv("data/플젝/구별로 나눈 csv/구로구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴
# Out:
# (60, 5)

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/구로구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/구로구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                518               425
# 2017-02                519               415
# 2017-03                525               410
# 2017-04                518               410
# 2017-05                544               424
# 2017-06                542               412
# 2017-07                555               440
# 2017-08                538               387
# 2017-09                547               379
# 2017-10                563               385
# 2017-11                560               434
# 2017-12                586               385
# 2018-01                590               434
# 2018-02                592               436
# 2018-03                575               436
# 2018-04                572               397
# 2018-05                584               423
# 2018-06                599               435
# 2018-07                624               428
# 2018-08                605               440
# 2018-09                593               452
# 2018-10                594               443
# 2018-11                623               453
# 2018-12                600               476
# 2019-01                600               471
# 2019-02                572               442
# 2019-03                588               437
# 2019-04                604               442
# 2019-05                665               448
# 2019-06                656               436
# 2019-07                711               448
# 2019-08                735               412
# 2019-09                709               417
# 2019-10                744               438
# 2019-11                760               467
# 2019-12                735               426
# 2020-01                722               454
# 2020-02                707               462
# 2020-03                689               466
# 2020-04                709               434
# 2020-05                718               459
# 2020-06                797               457
# 2020-07                823               477
# 2020-08                821               492
# 2020-09                834               500
# 2020-10                772               504
# 2020-11                742               528
# 2020-12                884               556
# 2021-01                915               544
# 2021-02                905               529
# 2021-03                930               539
# 2021-04                913               526
# 2021-05                956               559
# 2021-06                832               544
# 2021-07               1021               552
# 2021-08               1031               499
# 2021-09               1029               436
# 2021-10               1003               483
# 2021-11                999               539
# 2021-12                910               452

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     322
# 2017-02     266
# 2017-03     287
# 2017-04     281
# 2017-05     270
# 2017-06     248
# 2017-07     226
# 2017-08     251
# 2017-09     262
# 2017-10     256
# 2017-11     254
# 2017-12     216
# 2018-01     280
# 2018-02     200
# 2018-03     243
# 2018-04     199
# 2018-05     225
# 2018-06     223
# 2018-07     241
# 2018-08     222
# 2018-09     222
# 2018-10     217
# 2018-11     215
# 2018-12     171
# 2019-01     234
# 2019-02     198
# 2019-03     219
# 2019-04     188
# 2019-05     231
# 2019-06     190
# 2019-07     206
# 2019-08     180
# 2019-09     224
# 2019-10     205
# 2019-11     191
# 2019-12     194
# 2020-01     234
# 2020-02     179
# 2020-03     205
# 2020-04     160
# 2020-05     174
# 2020-06     200
# 2020-07     215
# 2020-08     171
# 2020-09     194
# 2020-10     209
# 2020-11     159
# 2020-12     169
# 2021-01     185
# 2021-02     166
# 2021-03     212
# 2021-04     194
# 2021-05     187
# 2021-06     203
# 2021-07     184
# 2021-08     208
# 2021-09     174
# 2021-10     181
# 2021-11     179
# 2021-12     166

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('구로구')

plt.legend(loc="upper left")

plt.show()
