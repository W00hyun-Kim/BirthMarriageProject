# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/성동구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/성동구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/성동구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                784               621
# 2017-02                754               602
# 2017-03                775               602
# 2017-04                804               588
# 2017-05                820               608
# 2017-06                790               604
# 2017-07                819               610
# 2017-08                808               614
# 2017-09                873               595
# 2017-10                869               600
# 2017-11                907               605
# 2017-12                931               611
# 2018-01                965               662
# 2018-02                987               659
# 2018-03                955               651
# 2018-04                986               649
# 2018-05               1020               654
# 2018-06               1015               633
# 2018-07               1092               655
# 2018-08               1125               659
# 2018-09               1188               673
# 2018-10               1159               653
# 2018-11               1067               693
# 2018-12               1202               690
# 2019-01               1126               692
# 2019-02               1182               672
# 2019-03               1065               649
# 2019-04               1155               669
# 2019-05               1140               662
# 2019-06               1234               678
# 2019-07               1265               654
# 2019-08               1249               667
# 2019-09               1208               678
# 2019-10               1276               674
# 2019-11               1266               696
# 2019-12               1282               718
# 2020-01               1294               709
# 2020-02               1319               753
# 2020-03               1332               720
# 2020-04               1297               721
# 2020-05               1299               731
# 2020-06               1426               785
# 2020-07               1532               771
# 2020-08               1570               800
# 2020-09               1592               755
# 2020-10               1577               815
# 2020-11               1623               821
# 2020-12               1686               838
# 2021-01               1698               869
# 2021-02               1707               813
# 2021-03               1826               818
# 2021-04               1827               816
# 2021-05               1884               822
# 2021-06               1761               825
# 2021-07               1757               836
# 2021-08               1859               849
# 2021-09               1919               840
# 2021-10               1900               854
# 2021-11               1766               881
# 2021-12               1952               876

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     251
# 2017-02     202
# 2017-03     214
# 2017-04     205
# 2017-05     217
# 2017-06     190
# 2017-07     208
# 2017-08     213
# 2017-09     211
# 2017-10     193
# 2017-11     196
# 2017-12     162
# 2018-01     216
# 2018-02     194
# 2018-03     223
# 2018-04     199
# 2018-05     190
# 2018-06     177
# 2018-07     209
# 2018-08     202
# 2018-09     188
# 2018-10     189
# 2018-11     179
# 2018-12     180
# 2019-01     217
# 2019-02     183
# 2019-03     186
# 2019-04     192
# 2019-05     199
# 2019-06     172
# 2019-07     176
# 2019-08     202
# 2019-09     165
# 2019-10     192
# 2019-11     160
# 2019-12     147
# 2020-01     193
# 2020-02     177
# 2020-03     165
# 2020-04     143
# 2020-05     182
# 2020-06     167
# 2020-07     159
# 2020-08     147
# 2020-09     181
# 2020-10     155
# 2020-11     162
# 2020-12     114
# 2021-01     155
# 2021-02     136
# 2021-03     176
# 2021-04     167
# 2021-05     154
# 2021-06     158
# 2021-07     156
# 2021-08     135
# 2021-09     148
# 2021-10     130
# 2021-11     146
# 2021-12     157

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('성동구')

plt.legend(loc="upper left")

plt.show()
