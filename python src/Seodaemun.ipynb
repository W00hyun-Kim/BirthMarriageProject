# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/서대문구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/서대문구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/서대문구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01                600               503
# 2017-02                592               524
# 2017-03                582               501
# 2017-04                625               511
# 2017-05                649               510
# 2017-06                656               532
# 2017-07                664               512
# 2017-08                670               487
# 2017-09                704               512
# 2017-10                707               526
# 2017-11                702               534
# 2017-12                723               543
# 2018-01                727               549
# 2018-02                702               524
# 2018-03                668               515
# 2018-04                695               506
# 2018-05                673               450
# 2018-06                733               517
# 2018-07                709               471
# 2018-08                796               554
# 2018-09                790               510
# 2018-10                741               525
# 2018-11                690               499
# 2018-12                813               544
# 2019-01                729               534
# 2019-02                750               537
# 2019-03                767               521
# 2019-04                776               501
# 2019-05                826               549
# 2019-06                904               554
# 2019-07                986               561
# 2019-08                940               521
# 2019-09                960               543
# 2019-10                889               562
# 2019-11                986               552
# 2019-12                985               574
# 2020-01                917               565
# 2020-02                907               556
# 2020-03                882               555
# 2020-04                840               565
# 2020-05                922               537
# 2020-06               1016               579
# 2020-07               1081               580
# 2020-08               1118               678
# 2020-09               1134               642
# 2020-10               1090               662
# 2020-11               1180               660
# 2020-12               1262               676
# 2021-01               1265               674
# 2021-02               1174               654
# 2021-03               1137               653
# 2021-04               1122               678
# 2021-05               1208               679
# 2021-06               1232               721
# 2021-07               1335               695
# 2021-08               1353               703
# 2021-09               1377               692
# 2021-10               1360               697
# 2021-11               1230               680
# 2021-12               1240               716

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     203
# 2017-02     171
# 2017-03     178
# 2017-04     178
# 2017-05     138
# 2017-06     155
# 2017-07     151
# 2017-08     182
# 2017-09     144
# 2017-10     143
# 2017-11     120
# 2017-12     148
# 2018-01     167
# 2018-02     135
# 2018-03     169
# 2018-04     141
# 2018-05     141
# 2018-06     128
# 2018-07     146
# 2018-08     145
# 2018-09     130
# 2018-10     126
# 2018-11     110
# 2018-12     109
# 2019-01     138
# 2019-02     121
# 2019-03     135
# 2019-04     139
# 2019-05     125
# 2019-06     134
# 2019-07     130
# 2019-08     115
# 2019-09     128
# 2019-10     122
# 2019-11     106
# 2019-12     128
# 2020-01     177
# 2020-02     116
# 2020-03     124
# 2020-04     129
# 2020-05     146
# 2020-06     125
# 2020-07     123
# 2020-08     131
# 2020-09     139
# 2020-10     109
# 2020-11     114
# 2020-12     100
# 2021-01     102
# 2021-02     128
# 2021-03     132
# 2021-04     117
# 2021-05     127
# 2021-06     117
# 2021-07     134
# 2021-08     123
# 2021-09     116
# 2021-10     114
# 2021-11     125
# 2021-12     117

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('서대문구')

plt.legend(loc="upper left")

plt.show()
