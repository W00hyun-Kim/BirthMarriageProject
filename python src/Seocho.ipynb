# %%
import pandas as pd
import matplotlib.pyplot as plt

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/서초구.csv", encoding="euc-kr")
df_last.shape   #행 열 순서로 나옴

plt.rc("font", family="Malgun Gothic")

df_last = pd.read_csv("data/플젝/구별로 나눈 csv/서초구.csv", encoding="euc-kr")
df_last2 = pd.read_csv("data/플젝/구별로 나눈 csv/서초구.csv", encoding="euc-kr")

pd.pivot_table(df_last, index=[" 일자"], values=[" 단위면적(㎡)당 매매가(만원)","단위면적(㎡)당 전세가(만원)"], aggfunc="mean")
# Out:
#           단위면적(㎡)당 매매가(만원)  단위면적(㎡)당 전세가(만원)
#  일자
# 2017-01               1137               698
# 2017-02               1140               687
# 2017-03               1162               625
# 2017-04               1180               677
# 2017-05               1237               721
# 2017-06               1244               722
# 2017-07               1304               740
# 2017-08               1170               680
# 2017-09               1250               738
# 2017-10               1263               745
# 2017-11               1344               699
# 2017-12               1302               737
# 2018-01               1377               730
# 2018-02               1322               669
# 2018-03               1272               730
# 2018-04               1300               733
# 2018-05               1402               752
# 2018-06               1467               774
# 2018-07               1577               816
# 2018-08               1687               774
# 2018-09               1569               839
# 2018-10               1357               829
# 2018-11               1530               868
# 2018-12               1347               837
# 2019-01               1298               790
# 2019-02               1508               796
# 2019-03               1651               708
# 2019-04               1597               740
# 2019-05               1730               737
# 2019-06               1796               746
# 2019-07               1731               803
# 2019-08               1757               728
# 2019-09               1830               773
# 2019-10               1821               789
# 2019-11               1760               810
# 2019-12               1769               838
# 2020-01               1402               840
# 2020-02               1586               782
# 2020-03               1593               859
# 2020-04               1844               859
# 2020-05               1875               937
# 2020-06               1868               946
# 2020-07               1874              1007
# 2020-08               1902               924
# 2020-09               1957              1001
# 2020-10               2072              1026
# 2020-11               2130              1016
# 2020-12               2145              1055
# 2021-01               2195              1012
# 2021-02               2076               985
# 2021-03               2000               845
# 2021-04               2188               961
# 2021-05               2160              1086
# 2021-06               2215               975
# 2021-07               2341              1035
# 2021-08               2288               744
# 2021-09               2373              1059
# 2021-10               2440              1060
# 2021-11               2236               984
# 2021-12               2079              1056

# %%
pd.pivot_table(df_last2, index=[" 일자"], values=[" 출생자 수"], aggfunc="mean")
# Out:
#           출생자 수
#  일자
# 2017-01     296
# 2017-02     276
# 2017-03     279
# 2017-04     257
# 2017-05     257
# 2017-06     260
# 2017-07     242
# 2017-08     254
# 2017-09     261
# 2017-10     241
# 2017-11     217
# 2017-12     199
# 2018-01     270
# 2018-02     239
# 2018-03     271
# 2018-04     223
# 2018-05     253
# 2018-06     226
# 2018-07     241
# 2018-08     248
# 2018-09     276
# 2018-10     229
# 2018-11     242
# 2018-12     201
# 2019-01     255
# 2019-02     196
# 2019-03     229
# 2019-04     206
# 2019-05     186
# 2019-06     191
# 2019-07     214
# 2019-08     204
# 2019-09     203
# 2019-10     232
# 2019-11     222
# 2019-12     174
# 2020-01     237
# 2020-02     193
# 2020-03     175
# 2020-04     193
# 2020-05     176
# 2020-06     201
# 2020-07     183
# 2020-08     167
# 2020-09     194
# 2020-10     187
# 2020-11     162
# 2020-12     170
# 2021-01     188
# 2021-02     180
# 2021-03     215
# 2021-04     179
# 2021-05     170
# 2021-06     183
# 2021-07     174
# 2021-08     212
# 2021-09     196
# 2021-10     196
# 2021-11     158
# 2021-12     162

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc("font", family="Malgun Gothic")
plt.rc('font', size=40)        # 기본 폰트 크기
plt.rc('axes', labelsize=20)   # x,y축 label 폰트 크기
plt.rc('xtick', labelsize=15)  # x축 눈금 폰트 크기 
plt.rc('ytick', labelsize=20)  # y축 눈금 폰트 크기
plt.rc('legend', fontsize=20)  # 범례 폰트 크기
plt.rc('figure', titlesize=50) # figure title 폰트 크기


g = df_last.groupby([" 일자"])[" 단위면적(㎡)당 매매가(만원)"].mean()
g2 = df_last.groupby([" 일자"])["단위면적(㎡)당 전세가(만원)"].mean()
g3 = df_last2.groupby([" 일자"])[" 출생자 수"].mean()


fig, ax1 = plt.subplots(figsize=(20, 15))
ax1.plot(g,label="단위면적(㎡)당 매매가(만원)")
ax1.plot(g2,label="단위면적(㎡)당 전세가(만원)")

plt.xticks(rotation=90)

plt.legend(loc="upper right")


plt.xlabel('일자')
plt.ylabel('단위면적(㎡)당 금액(만원)')


ax2 = ax1.twinx()
plt.ylabel('출생자 수')

ax2.plot(g3, color='deeppink',label="출생자 수")

plt.title('서초구')

plt.legend(loc="upper left")

plt.show()
